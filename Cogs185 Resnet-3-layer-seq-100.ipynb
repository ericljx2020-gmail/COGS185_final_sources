# %%
import os

# Remove incompatible cuDNN versions from LD_LIBRARY_PATH
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda/lib64:' + os.environ['LD_LIBRARY_PATH']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from torch.distributions import Categorical

# Ensure reproducibility
torch.manual_seed(0)
np.random.seed(0)

# %%
# Data I/O
data = open('input.txt', 'r').read()  # This should be a simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyperparameters
hidden_size = 100  # Size of hidden layer of neurons
seq_len = 100  # Number of steps to unroll the RNN for
learning_rate = 5e-3
epochs = 20
save_path = 'model.pth'
op_seq_len = 200  # Length of the output sequence
num_layers = 3

# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# data has 1115394 characters, 65 unique.

# %%
class ResidualLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(ResidualLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(input_size, hidden_size)  # Change embedding size to match hidden size
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers=num_layers, batch_first=True)
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq, hidden_state):
        embedding = self.embedding(input_seq)
        residual = embedding.clone()  # Use clone to avoid in-place operations
        output, hidden_state = self.lstm(embedding, hidden_state)
        output = output + residual  # Add residual connection
        output = self.decoder(output)
        return output, hidden_state

    def initHidden(self):
        return (torch.zeros(self.num_layers, 1, self.hidden_size).to(device),
                torch.zeros(self.num_layers, 1, self.hidden_size).to(device))

# Instantiate model, loss function and optimizer
rnn = ResidualLSTM(vocab_size, hidden_size, vocab_size, num_layers).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), lr=learning_rate)

# %%
# Convert a sequence of characters to a tensor
def char_tensor(seq):
    tensor = torch.tensor([char_to_ix[ch] for ch in seq], dtype=torch.long).unsqueeze(0).to(device)
    return tensor

# %%
losses = []
epochs_cnt = []

# Training loop
for i_epoch in range(1, epochs + 1):
    # Random starting point (1st 100 chars) from data to begin
    data_ptr = np.random.randint(100)
    n = 0
    running_loss = 0
    hidden_state = rnn.initHidden()

    while True:
        input_seq = char_tensor(data[data_ptr : data_ptr + seq_len])
        target_seq = char_tensor(data[data_ptr + 1 : data_ptr + seq_len + 1])

        # Forward pass
        output, hidden_state = rnn(input_seq, hidden_state)
        output = output.view(-1, vocab_size)
        target_seq = target_seq.view(-1)

        # Compute loss
        loss = criterion(output, target_seq)
        running_loss += loss.item()

        # Compute gradients and take optimizer step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Detach hidden state to prevent backprop through entire training history
        hidden_state = (hidden_state[0].detach(), hidden_state[1].detach())

        # Update the data pointer
        data_ptr += seq_len
        n += 1

        # If at end of data, break
        if data_ptr + seq_len + 1 > data_size:
            break

    # Print loss and save weights after every epoch
    print("Epoch: {0} \t Loss: {1:.8f}".format(i_epoch, running_loss / n))
    epochs_cnt.append(i_epoch)
    losses.append(running_loss / n)
    torch.save(rnn.state_dict(), save_path)

    # Sample / generate a text sequence after every epoch
    data_ptr = 0
    hidden_state = rnn.initHidden()

    # Random character from data to begin
    rand_index = np.random.randint(data_size - 1)
    input_seq = char_tensor(data[rand_index : rand_index + 1])

    print("----------------------------------------")
    while True:
        # Forward pass
        output, hidden_state = rnn(input_seq, hidden_state)

        # Construct categorical distribution and sample a character
        output = F.softmax(torch.squeeze(output), dim=0)
        dist = Categorical(output)
        index = dist.sample()

        # Print the sampled character
        print(ix_to_char[index.item()], end='')

        # Next input is current output
        input_seq = char_tensor(ix_to_char[index.item()])
        data_ptr += 1

        if data_ptr > op_seq_len:
            break

    print("\n----------------------------------------")
# Out:
# Epoch: 1 	 Loss: 1.75300592
# ----------------------------------------
# n: or upon
# As for with more mind, and letguebor.
#
# ALONSO:
# I did nothings speaks,
# In it ladon, as speak rown no mell, at of not what lave, terealtissed, and mothery the smelces attend let you nebson, cl
# ----------------------------------------
# Epoch: 2 	 Loss: 1.58704415
# ----------------------------------------
# avandward of I knowact by you
# It is of long shall me think with causom gew a daminglad my tall,
# Have twits feech I lave three love stilple;
# Antealt winous wonde Righter gentlemently send too, sir,
# I do
# ----------------------------------------
# Epoch: 3 	 Loss: 1.56211218
# ----------------------------------------
# Amfisctleness is foolished itles Barn.
#
# EBANIO:
# Their storm'd, as in stain'd would I notgaisty, was sakes thou so spokenallofy wertle eyes of my link me in ratuer of hering.
#
# GONZALO:
# When will by succ
# ----------------------------------------
# Epoch: 4 	 Loss: 1.55787802
# ----------------------------------------
# we never heat winstep us noblects!
#
# ANTONIO:
# Which lasts.
#
# GONSASTIO:
#
# SEBASTIAN:
# Who mother to helty?
#
# SEBASTIAN:
# By Dirrant
# Which, ,ranely ewice!
#
# ANTONIO:
# Go dogbee, my brings, God.
#
# GONZALO:
# Why us
# ----------------------------------------
# Epoch: 5 	 Loss: 1.55261090
# ----------------------------------------
# percy:
# What Tunis!
# Old do Anfoe forth: to did the noptt all conslauden lordor most slew will so eny.
#
# SEBASTIAN:
# Call her bang at his
# maided, streeth of me go, signise, all not find youx since,
# Of lies
# ----------------------------------------
# Epoch: 6 	 Loss: 1.55576632
# ----------------------------------------
# ord sir,
# And ploudelly.
#
# Woeth:
# Weavy
# Out it.
#
# ANTONIO:
# Which our that our accomed.
#
# SEBASTIAN:
# ANque you.
# No loven and neither us, as as sphesontamit.
#
# GONZALON:
# I wing,
# again.
#
# GONZALO:
# In they art;
# ----------------------------------------
# Epoch: 7 	 Loss: 1.56065058
# ----------------------------------------
# iet as stong thou do fell that, in thence no moinness untember not no dandal, and two
# Louble, within it not in't prush in my heavy and paltar's provest to me in usiduise.
#
# ANTONIO:
# We're all I speak, i
# ----------------------------------------
# Epoch: 8 	 Loss: 1.56354394
# ----------------------------------------
# I hoat.
#
# GONZALO:
# Vespey upon alt your secreng my done.
#
# GONZALO:
#
# GONTIAN:
#
# GONZALO:
# Byhaven'd Spece.
#
# GONZALO:
# Natit you on you face staty.
#
# VIANTIONIO:
# And will speak to the womin.
#
# STRANTONIAT:
# To
# ----------------------------------------
# Epoch: 9 	 Loss: 1.56702392
# ----------------------------------------
# y wrows: and Herish--
# An not yet a hoppen the spoke my send a sweather followdorysos
# to your mind.
#
# GOLONIO:
# No frother,
# Sents myself not in my assand, juten virdial fints were all: wherela-steene cont
# ----------------------------------------
# Epoch: 10 	 Loss: 1.57272170
# ----------------------------------------
# GO: A wear, by spariey-fit.
#
# GONZALO:
# Vea, cannest Sandaged it , on.
#
# Would Be amcest.
#
# ANTONIO:
# Where then, thou no kustal feiting.
#
# ASTIAN: I plaided should son, arm: Not musty, ado?
#
# FERIBASTIAN:
# Si
# ----------------------------------------
# Epoch: 11 	 Loss: 1.57420212
# ----------------------------------------
# Cat stople, live!
#
# GONZALO:
# Suft awair.
#
# ALONSO:
# Sir, who, like guothed.
#
# DRIAN:
# And thou thine rememblusthanour.
#
# SenCHAN:
# It shall behrrong bency.
#
# SEBASTIAN:
# The gentcage: servinty Vorning by eye; w
# ----------------------------------------
# Epoch: 12 	 Loss: 1.58011204
# ----------------------------------------
# t:
# That sattle your gode, the deswer: this, netth, a forementionce maid I nem my tongue as They may posent them which bring; what weaked mean
# Ho'sest in
# him,
# Would not
# My ratul happes scion.
#
# GONZALO:
#
# ----------------------------------------
# Epoch: 13 	 Loss: 1.58211677
# ----------------------------------------
# , traving, 'Dic plast but in my sin help.
#
# MIANIALO:
# We'llios fashed appeaburate?
#
# ANTONIO:
# And I come dive my lies of as that for use queen.
#
# ASTONTO GONZALO:
# Alas ther with sleart my uney beyon.
#
# Cri
# ----------------------------------------
# Epoch: 14 	 Loss: 1.58737807
# ----------------------------------------
# row:'d it the sua whuch, touchest to all brugin's mine trastys all you make.
#
# TONSELO:
# We woast thus; and the armel on it.
#
# GONZALO:
# Wench, well talks it was eyen ophers;
# burshorn
# Wido one at saccaster
# ----------------------------------------
# Epoch: 15 	 Loss: 1.59270651
# ----------------------------------------
# antant:
# Ay it affir them we'la meat
# not
# in; I sayer in the far mistree; I tchile warsivy qua, which we my ginther of sure beaul is the fate, I have lagited me, as little,--
#
#
# PEBASTO:
# O, hath this son
# ----------------------------------------
# Epoch: 16 	 Loss: 1.59955783
# ----------------------------------------
# &CENTIAN:
# Not neperny Vings: I Now gonish lay
# When rungients so so most rolies. We do, heager mastery to all of all mistress two ave than the mine in you giviled?
#
# ANTONIO:
# Wible be; is all.
#
# ASTIANIO:
# ----------------------------------------
# Epoch: 17 	 Loss: 1.61364721
# ----------------------------------------
# So go go we and laysly-made, I thankes with to it all all not, Melmabla thangant as him a good wontet.
#
# Lookin:
# Want
# As our eeble
# and wald againsthess of your rate, whold sucty-to so.'ther it spilincan
# ----------------------------------------
# Epoch: 18 	 Loss: 1.62127118
# ----------------------------------------
# ther'st: boundly!
#
# GONZALO:
# You you your doof upon his resime and vitio! o'rre; you are the will of all gutle.
#
# GONZALO:
# Ay! by misttisy
# He with manny.
# What of ynue,
# Thou were all our bend you weep.
#
# G
# ----------------------------------------
# Epoch: 19 	 Loss: 1.62006370
# ----------------------------------------
# nibSTh need. Twiratcha, A clessa;
# To won behined forth! Olth: they feal.
#
# ANTONIO:
# No matal.
#
# ANSTON:
# The godsle.
#
# ANTONIO:
# Of if it swellua!
# Who reford becRUCHANSerie, is speest
# Whence, all she sleep
# ----------------------------------------
# Epoch: 20 	 Loss: 1.63658006
# ----------------------------------------
# h: yaul all say speaks as I will not my lord: I will cas it
# Worla indent.
#
# GONZALO:
# Why rest as by inmound fellow: queen.
#
# SEBASTIAN:
# You comforthy themratio catic,
# she be life advinion and allass.
#
# GO
# ----------------------------------------

# %%
from matplotlib import pyplot as plt
plt.plot(epochs_cnt, losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.show()
