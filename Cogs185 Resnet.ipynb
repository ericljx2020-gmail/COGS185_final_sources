# %%
import os

# Remove incompatible cuDNN versions from LD_LIBRARY_PATH
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda/lib64:' + os.environ['LD_LIBRARY_PATH']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from torch.distributions import Categorical

# Ensure reproducibility
torch.manual_seed(0)
np.random.seed(0)

# %%
# Data I/O
data = open('input.txt', 'r').read()  # This should be a simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyperparameters
hidden_size = 100  # Size of hidden layer of neurons
seq_len = 25  # Number of steps to unroll the RNN for
learning_rate = 5e-3
epochs = 20
save_path = 'model.pth'
op_seq_len = 200  # Length of the output sequence
num_layers = 1

# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# data has 1115394 characters, 65 unique.

# %%
class ResidualLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(ResidualLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(input_size, hidden_size)  # Change embedding size to match hidden size
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers=num_layers, batch_first=True)
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq, hidden_state):
        embedding = self.embedding(input_seq)
        residual = embedding.clone()  # Use clone to avoid in-place operations
        output, hidden_state = self.lstm(embedding, hidden_state)
        output = output + residual  # Add residual connection
        output = self.decoder(output)
        return output, hidden_state

    def initHidden(self):
        return (torch.zeros(self.num_layers, 1, self.hidden_size).to(device),
                torch.zeros(self.num_layers, 1, self.hidden_size).to(device))

# Instantiate model, loss function and optimizer
rnn = ResidualLSTM(vocab_size, hidden_size, vocab_size, num_layers).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), lr=learning_rate)

# %%
# Convert a sequence of characters to a tensor
def char_tensor(seq):
    tensor = torch.tensor([char_to_ix[ch] for ch in seq], dtype=torch.long).unsqueeze(0).to(device)
    return tensor

# %%
losses = []
epochs_cnt = []

# Training loop
for i_epoch in range(1, epochs + 1):
    # Random starting point (1st 100 chars) from data to begin
    data_ptr = np.random.randint(100)
    n = 0
    running_loss = 0
    hidden_state = rnn.initHidden()

    while True:
        input_seq = char_tensor(data[data_ptr : data_ptr + seq_len])
        target_seq = char_tensor(data[data_ptr + 1 : data_ptr + seq_len + 1])

        # Forward pass
        output, hidden_state = rnn(input_seq, hidden_state)
        output = output.view(-1, vocab_size)
        target_seq = target_seq.view(-1)

        # Compute loss
        loss = criterion(output, target_seq)
        running_loss += loss.item()

        # Compute gradients and take optimizer step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Detach hidden state to prevent backprop through entire training history
        hidden_state = (hidden_state[0].detach(), hidden_state[1].detach())

        # Update the data pointer
        data_ptr += seq_len
        n += 1

        # If at end of data, break
        if data_ptr + seq_len + 1 > data_size:
            break

    # Print loss and save weights after every epoch
    print("Epoch: {0} \t Loss: {1:.8f}".format(i_epoch, running_loss / n))
    epochs_cnt.append(i_epoch)
    losses.append(running_loss / n)
    torch.save(rnn.state_dict(), save_path)

    # Sample / generate a text sequence after every epoch
    data_ptr = 0
    hidden_state = rnn.initHidden()

    # Random character from data to begin
    rand_index = np.random.randint(data_size - 1)
    input_seq = char_tensor(data[rand_index : rand_index + 1])

    print("----------------------------------------")
    while True:
        # Forward pass
        output, hidden_state = rnn(input_seq, hidden_state)

        # Construct categorical distribution and sample a character
        output = F.softmax(torch.squeeze(output), dim=0)
        dist = Categorical(output)
        index = dist.sample()

        # Print the sampled character
        print(ix_to_char[index.item()], end='')

        # Next input is current output
        input_seq = char_tensor(ix_to_char[index.item()])
        data_ptr += 1

        if data_ptr > op_seq_len:
            break

    print("\n----------------------------------------")
# Out:
# Epoch: 1 	 Loss: 1.77124113
# ----------------------------------------
#  speakeany yould my? Not yar sinkinuso!
# Whath? I ne, they at ess afist?
#
# SEBASTIAN:
# Whend,
# Sweath, assst; kind thou, oag croul me, am of lef speso heavy you slipe. Or cressew-salts. Would. Good
# Thanked
# ----------------------------------------
# Epoch: 2 	 Loss: 1.72121499
# ----------------------------------------
#  spreast:
# Dalibly stasing at
# O most? amink,
# The will leatm, and us? What not percees spist
# Layt thou in they nimenwars of Plee-wst, Mining? King Firldon'd mast, Hea,
# Didn; you smy trangeenatle nat mett
# ----------------------------------------
# Epoch: 3 	 Loss: 1.73662398
# ----------------------------------------
# That upupmy of with with thyquran,
# As speakinst go than good like of with.
#
# ANTONIO:
# Who the moost emo;
# So
# 'Twis more?
# Antiagers it. That I lory; will me yet I is amondy offent
# Thou.
#
# ANTONIO:
# Sefibtin
# ----------------------------------------
# Epoch: 4 	 Loss: 1.75480724
# ----------------------------------------
# for at sonin
# by is a stice ander quksition; fing. Then which upon salis thy stusperthing?
# Who pade
# Whis
# natturazatt
# Nos'let if what not, and aso, of ca saps my wish
# What angelecess, my bearst thy art o
# ----------------------------------------
# Epoch: 5 	 Loss: 1.76678645
# ----------------------------------------
#  ome.
#
# SEBANZALONIO:
# I leyy,
# Bit eye! speak they? Nout
# Thinwerd, alk,
# Sind me!
# Will spease,
# Be; breetleyo.
#
# SEBASTIAN:
# I
# Nothar,
# The main sleep
# whortlees safeint It combst,
# Here:
# Nor in't she stongs
# Of
# ----------------------------------------
# Epoch: 6 	 Loss: 1.77592726
# ----------------------------------------
# out why meit sither. meatfer
# And, and 'timeces smepping oppy? But the claming. I sweet and adsiddows--bray finds gritten,
# Seet be is if I widwill moo
# Whage!
#
# SEBASTIAN:
# I sost themby taking?
# SEBASTIAN
# ----------------------------------------
# Epoch: 7 	 Loss: 1.80179576
# ----------------------------------------
# table.
#
# STONIO:
# Seman areting my a have,--se, so raverool. didared, slepesting agith
#  yetce. of the streass hermither?
#
# SEBASTIAN:
# What to a havy 'mewan
# That I why? I pot a crows gresh Have pray saty,
#
# ----------------------------------------
# Epoch: 8 	 Loss: 1.80983244
# ----------------------------------------
# It yor ye comfrotheny hip leaving not bair your eycomf,
# What. Well sonsp the speed sutic comou.
#
# ANTONIO:
# Bend:
# Is slaky thy ger Cath as th. I hatcey. For Lord, his shall is It at yelchoseny, I as asty
# ----------------------------------------
# Epoch: 9 	 Loss: 1.82687250
# ----------------------------------------
# omn; yes
# What spying? It rast.
#
# ANTONIO:
# That, you, good yet I suped not not kitting a mast eymest this men in yeash'd,
# No mince: the retcand,
# Thou mastute.
# To by,
# I, see why dimscans nedout,
# On caren,
# ----------------------------------------
# Epoch: 10 	 Loss: 1.83173931
# ----------------------------------------
# giin thes spliast: No.
# Angling.
#
# SEBASTIAN:
# I awap. I stress they slepp thyse, It ball by heavy you thy that swea yout with grow, your dementensy.
#
# SEBASTIAN:
# Not,
# Whomong.
#
# ANTONIO:
# It for the spost t
# ----------------------------------------
# Epoch: 11 	 Loss: 1.83508912
# ----------------------------------------
# Islewhoster And she by eye. Wour I seel!
#
# ANTONIO:
# O I mable give?
#
# GONZALO:
# SEBASTIAN:
# Who soopling oge your so ris they els I grost it my end renangie
# it they fanisly enserssy; fromatre not seyell to
# ----------------------------------------
# Epoch: 12 	 Loss: 1.83964953
# ----------------------------------------
# rtha:
# Dotard that frowa; I divy laving Itent marris boke me thy eltang fiar?
#
# SEBASTIAN:
# Buzy I do ceen swall lope: you you lope tith thou I fa'har sead do din this without so so, thy on g Man;
# 'Twean
# ----------------------------------------
# Epoch: 13 	 Loss: 1.84969167
# ----------------------------------------
# b,
# Pa spepit yee, sin; forther
# I swean it thy fastithousse? Seyeres,
# And this speifet hingha!
# Why fivish.
# The, your by It as I so sigherp thith will thou not dnow, ambleataf my thus creing.
#
# SEBASTIAN:
# ----------------------------------------
# Epoch: 14 	 Loss: 1.85015353
# ----------------------------------------
# uresh. Sently neuss sleel stanger,
# wintle was ghere bate sweep,--said,--I amoth ead!
# This asless
# Not here.
# Whis eemity theaks spil my to is yangs of is nathistake, this med, with whisty seat
# Workesse a
# ----------------------------------------
# Epoch: 15 	 Loss: 1.85877014
# ----------------------------------------
# out then agnishbast lastle isles My remys, thet, on her
# Anced what sakly the fisty mays saughes at threed of thet
# Deint.
#
# SEBASTIAN:
# What patch in eyon.
#
# SEBASTIAN:
# Whaks the he
# Twirrst of sty liend do
# ----------------------------------------
# Epoch: 16 	 Loss: 1.85379526
# ----------------------------------------
# ow-not thee, Kinds:
# Dine.
#
# ANTONIO:
# It my that poinistly of they cold with a losslives; seep thou im.
#
# ASEBASTIO:
# In sirse, sing pootisinigh it-thy amblisfemagee: crows to of not?--that I spubind, in o
# ----------------------------------------
# Epoch: 17 	 Loss: 1.85443477
# ----------------------------------------
# It foth you ord beare It they sly rot, affeac?
#
# SEBASTIAN:--
# butio a slull be rock?
# Which yough heasty; ponters as batwe,
# Wonsin is is usure,
# What thy llowongsin in of ANain,
# You what,
# I this wasp'de
# O
# ----------------------------------------
# Epoch: 18 	 Loss: 1.87521335
# ----------------------------------------
# ise host not sledong.
#
# ANTONIO:
# With.
#
# ANTONIO:
# Notst thy quiend.
#
# SEBASTIAN:
# Vely a self king dimal staboagey mouth, thou shookbet thou so? I sispak,
# It kearnour thou:
# The whove that?
# When. Whase.
#
# SE
# ----------------------------------------
# Epoch: 19 	 Loss: 1.87393161
# ----------------------------------------
# rinfour not, mile, earselfe! Whe warial you wasker sto clovy?
#
# GONZALO:
# Heave.
#
# SEBASTIANIO:
# Whys Fo dreeposking by stregin are laugh of good your cepty ases you his isper. What not we mindand your spe
# ----------------------------------------
# Epoch: 20 	 Loss: 1.88423608
# ----------------------------------------
# enceint not art wamstrea may all thy comewor? in o' is with stay grem,
# Loke:----ming Dot ry asweep. And us dould your baking when stovy.
#
# ANTONIO:
# Why may cure does wele at littaking.
#
# ANTONIO:
# Aliveak
# ----------------------------------------

# %%
from matplotlib import pyplot as plt
plt.plot(epochs_cnt, losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.show()
