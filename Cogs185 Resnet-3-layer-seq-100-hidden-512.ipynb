# %%
import os

# Remove incompatible cuDNN versions from LD_LIBRARY_PATH
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda/lib64:' + os.environ['LD_LIBRARY_PATH']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from torch.distributions import Categorical

# Ensure reproducibility
torch.manual_seed(0)
np.random.seed(0)

# %%
# Data I/O
data = open('input.txt', 'r').read()  # This should be a simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# Hyperparameters
hidden_size = 256  # Size of hidden layer of neurons
seq_len = 100  # Number of steps to unroll the RNN for
learning_rate = 5e-3
epochs = 20
save_path = 'model.pth'
op_seq_len = 200  # Length of the output sequence
num_layers = 3

# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# data has 1115394 characters, 65 unique.

# %%
class ResidualLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(ResidualLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(input_size, hidden_size)  # Change embedding size to match hidden size
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers=num_layers, batch_first=True)
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq, hidden_state):
        embedding = self.embedding(input_seq)
        residual = embedding.clone()  # Use clone to avoid in-place operations
        output, hidden_state = self.lstm(embedding, hidden_state)
        output = output + residual  # Add residual connection
        output = self.decoder(output)
        return output, hidden_state

    def initHidden(self):
        return (torch.zeros(self.num_layers, 1, self.hidden_size).to(device),
                torch.zeros(self.num_layers, 1, self.hidden_size).to(device))

# Instantiate model, loss function and optimizer
rnn = ResidualLSTM(vocab_size, hidden_size, vocab_size, num_layers).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), lr=learning_rate)

# %%
# Convert a sequence of characters to a tensor
def char_tensor(seq):
    tensor = torch.tensor([char_to_ix[ch] for ch in seq], dtype=torch.long).unsqueeze(0).to(device)
    return tensor

# %%
losses = []
epochs_cnt = []

# Training loop
for i_epoch in range(1, epochs + 1):
    # Random starting point (1st 100 chars) from data to begin
    data_ptr = np.random.randint(100)
    n = 0
    running_loss = 0
    hidden_state = rnn.initHidden()

    while True:
        input_seq = char_tensor(data[data_ptr : data_ptr + seq_len])
        target_seq = char_tensor(data[data_ptr + 1 : data_ptr + seq_len + 1])

        # Forward pass
        output, hidden_state = rnn(input_seq, hidden_state)
        output = output.view(-1, vocab_size)
        target_seq = target_seq.view(-1)

        # Compute loss
        loss = criterion(output, target_seq)
        running_loss += loss.item()

        # Compute gradients and take optimizer step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Detach hidden state to prevent backprop through entire training history
        hidden_state = (hidden_state[0].detach(), hidden_state[1].detach())

        # Update the data pointer
        data_ptr += seq_len
        n += 1

        # If at end of data, break
        if data_ptr + seq_len + 1 > data_size:
            break

    # Print loss and save weights after every epoch
    print("Epoch: {0} \t Loss: {1:.8f}".format(i_epoch, running_loss / n))
    epochs_cnt.append(i_epoch)
    losses.append(running_loss / n)
    torch.save(rnn.state_dict(), save_path)

    # Sample / generate a text sequence after every epoch
    data_ptr = 0
    hidden_state = rnn.initHidden()

    # Random character from data to begin
    rand_index = np.random.randint(data_size - 1)
    input_seq = char_tensor(data[rand_index : rand_index + 1])

    print("----------------------------------------")
    while True:
        # Forward pass
        output, hidden_state = rnn(input_seq, hidden_state)

        # Construct categorical distribution and sample a character
        output = F.softmax(torch.squeeze(output), dim=0)
        dist = Categorical(output)
        index = dist.sample()

        # Print the sampled character
        print(ix_to_char[index.item()], end='')

        # Next input is current output
        input_seq = char_tensor(ix_to_char[index.item()])
        data_ptr += 1

        if data_ptr > op_seq_len:
            break

    print("\n----------------------------------------")
# Out:
# Epoch: 1 	 Loss: 1.75874936
# ----------------------------------------
# .
#
# SEBASTIAN:
# No speak
# Sell me, by. but I so pastor
# It in Caligh, he, steat you of comple
# Would vile
# ammen?
#
# SEBASTIAN:
# 'eavy best, Ity your father'd soand.
#
# ANTONIO:
# Nay?
#
# ANTONIO:
# You king wath;
# What
# ----------------------------------------
# Epoch: 2 	 Loss: 1.59185503
# ----------------------------------------
# m?
#
# MIRIAN:
# When a treat a stoop trity; as he do them:
# And, eye, sir, and nothing; in't, nats. He head was here weilg in wain:-speech for youthits: by the lost way,
# Would.
#
# ARION:
# No, that num, in eyc
# ----------------------------------------
# Epoch: 3 	 Loss: 1.56459773
# ----------------------------------------
# Promis warriateth It and with by thy broughts.
#
# ALONSO:
# Fow't you all warn makest forgivy!
# I
# that your recestuits
# 'Sembing of Party.
#
# ANTONIO:
# No livy?
# But Distrate should narried as yast, and lionging
# ----------------------------------------
# Epoch: 4 	 Loss: 1.55214441
# ----------------------------------------
# EBCe ises of you man that you watt still misstronguge.
#
# PRIRISTO: Well, but that I am nircakian's better undono, retila exed,
# Now this yival.
#
# GONZALO:
# Your ear first,
# Would I wou sold rague, I am taxe
# ----------------------------------------
# Epoch: 5 	 Loss: 1.54599742
# ----------------------------------------
# e won'tended, nothing than their scauntand I people, as not larouson;
# Would nature, ender take me.
#
# ALONSO:
#
# ANTONIO:
# Thou was corruence, sucherest if nothing bo, like; taketh'd,
# When the find midgines
# ----------------------------------------
# Epoch: 6 	 Loss: 1.54007148
# ----------------------------------------
# knul.
#
# PRIAN:
# Nay not
# I at enanswork,--who givens of ochald,
# My servable, writher that on attend avout, mak prayings beeten win.
#
# ALONSO:
# No maid, it
# sworn in;
# whichens, are effecrecers, all beloin all
# ----------------------------------------
# Epoch: 7 	 Loss: 1.53934017
# ----------------------------------------
# r with malilling.
#
#
# TRIONIA:
# Noned, my quarling.
#
# SEBRIO:
# We didst you have all our hath his tragging.
#
# GONZALO:
# Sped disticy against!
#
# GONZALO:
# Thou art as you are my father' a
# sing he do
# With aporte
# ----------------------------------------
# Epoch: 8 	 Loss: 1.54033478
# ----------------------------------------
# LONZALO:
# No, It some and stifled wido there,
#
# My meash:
# Your subjecteshy; he rivy: atey;
# Thereon no mocatistign Carnish at my girty.
#
# SEBASTO:
# No, when just mf let's
# ratter and larace;
# And,-
# I of theel
# ----------------------------------------
# Epoch: 9 	 Loss: 1.55375541
# ----------------------------------------
# plucelus as thin stry.
#
# ALONSO:
# Ay I am SERIAN:
# Would uthern'd sister,
# Gone of whither not rope up it: all on how slavy;
# And concap your soulost now I upome so drenks, then, no ming.
#
# ANTONIO:
# No sin,
# ----------------------------------------
# Epoch: 10 	 Loss: 1.56480467
# ----------------------------------------
# ;
# ONZAN.
#
# IAY:
#
# DUCON:
# Thoushighing entraep with some it, Is thou enity. Who let you hope Donguoth a tenther, in retoren at on.
#
# SEBASTIAN:
# And, at itcled powleral were save niss hor it word all you.
#
#
# ----------------------------------------
# Epoch: 11 	 Loss: 1.57008505
# ----------------------------------------
# o,
# Bland, shefe nit pety fell figh'st sin them lord, she gillsly stollan slofe upon
# real queen; wespetate long.
#
# VIRIO:
# Mosting gyes purge to fellow'd
# As given up, Hom nitnemend a father's certague
# Wit
# ----------------------------------------
# Epoch: 12 	 Loss: 1.58904128
# ----------------------------------------
# GONZAN:
# Sir, no hepring plance errmed times at her time, Thine, more end in
# thee? whath upos you?
#
# GONZALO:
# Sir, nor ower them so lith your cout yhoord your lord
# indounty somming.
#
# SEBASTIAN:
# O: I asse
# ----------------------------------------
# Epoch: 13 	 Loss: 1.60283722
# ----------------------------------------
# ghem:
# And
# With too so of wovath know?
#
# EBASTIAN:
# I is the love sleivens; I heavy. Not not thrould,
# Well, foulowey Wow' upon wearonhess?
#
# ANTONIO:
# Whisply ling of fit you
# That by mising.
#
# Mithee in myst
# ----------------------------------------
# Epoch: 14 	 Loss: 1.61305385
# ----------------------------------------
# ink
# Yet minstning us sir, you some;
# So you marryment. You as my vervy.
#
# Beither:
# And you alloceedry on the strikitiany?
#
# ANTONIO:
# Dishinks for mine; so
# Carrant as lenoul! Kink then cuctar upon the spir
# ----------------------------------------
# Epoch: 15 	 Loss: 1.62634565
# ----------------------------------------
# catien the
# met it will thou sleyous, -
#
# SEBASTIAN:
# Whyeelt here maust me, adviset: but.
#
# ANTONIO:
# I'ling, but you litr their.
#
# NIRIASO:
# And, let me ty withgre againing. Govy stong my father,
# Wath other
# ----------------------------------------
# Epoch: 16 	 Loss: 1.63520451
# ----------------------------------------
# l.
#
# SEBASTO:
# They exting a natwingan with your much selfer i' loves
#
# GONZALO:
# Nakenty we wroke; 'twere their spirith. the wit
# ose; of Nard that.
#
# EBASTIO:
# Whaty siff our retives yot so eirm-delights
# by
# ----------------------------------------
# Epoch: 17 	 Loss: 1.64701850
# ----------------------------------------
# in,
# Go speet no dindore or woman;
# Nave will to firns,
# What baccorrence, swear me on golden agavy:
# Which I may fremeng-with mil. Thou of wlaced,
# Thy le, of offer feather.
#
# ANTONIO:
# No. Sinor subjest he'
# ----------------------------------------
# Epoch: 18 	 Loss: 1.67725027
# ----------------------------------------
# stain feet: Dingrac stit
# And die it my semfing ever it will wath
# With Presend as I sive aur knocl.
#
# ANTONIO:
# Sirst nother menterspeasit?
#
# Weash SEBASTIAN:
# When I am a dattible, a mar?
#
# ALONSEBALO:
# Why,
# ----------------------------------------
# Epoch: 19 	 Loss: 1.72731204
# ----------------------------------------
# edn cellary
# That so that you renitienty is the gird.
#
# ASTO:
# Ay, drinkle nease,
# Lorth in the lords upon ryson, slay of dimem my give all.
#
# MIRIALO:
# I am aslan dientems, at Caret tom moulsime me:
# Why, by
# ----------------------------------------
# Epoch: 20 	 Loss: 1.89921872
# ----------------------------------------
#
# to sly tt an ofintimatherte sronerg
#
# ALONSTO:
# Well aghis,
# Wh?
# So itayelate, theme an heare,
#
# NIBASTIAN:
# An Gonestseo, is as let anme iseitsenter seizelt
# Whel the wase at ey it in abro'do,
#
# SEBASTIANSO
# ----------------------------------------

# %%
from matplotlib import pyplot as plt
plt.plot(epochs_cnt, losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.show()

# %%
### TESTING SAMPLES
test_input = "H"
input_seq = char_tensor(test_input[0: seq_len])
print("----------------------------------------")
while True:
    # Forward pass
    output, hidden_state = rnn(input_seq, hidden_state)

    # Construct categorical distribution and sample a character
    output = F.softmax(torch.squeeze(output), dim=0)
    dist = Categorical(output)
    index = dist.sample()

    # Print the sampled character
    print(ix_to_char[index.item()], end='')

    # Next input is current output
    input_seq = char_tensor(ix_to_char[index.item()])
    data_ptr += 1

#     if data_ptr > op_seq_len:
#         break

print("\n----------------------------------------")
# Out:
# ----------------------------------------
# , is keld.
#
# I killeasly dor yeth:
# Wing.
#
#
# ANTONIONIO:
# Whe morth!
#
# ANTIALO,
# Non your wouldurislisponnkerewolthease ispes whis mather wour ase upon that the menclewadth and thim soct give
# Preas.
#
# Whatle mimge.
#
# fire:
# To Wher sirnop,
# 'tisslent
# Where is bact my arth so, you nivitly love him wart; affefesuch ine yo,
# ' ase aself iting the eoned with slyesesle in cronth or bace't.
#
# SEBASTIAN:
# An o what rere. aw imatamitivuce. What sownt,
# Whilitags My tilige.
# The disileccelaurdmeste io boren that quan you that islaitinge. Wellary fause hims spees!
# Word sir, yeed ather.
# What af the what heak nw she do do yearet themehe shall shercay of
# ANTIALO:
# And fornocet, of thee.
# We. my do caf you, siry they anpur with tro nathers trong you forne-ceat notich you't hong.
#
# ANTIALO:
# Sionond yere; youghty?
#
# ANTONSO:
# What eape as you do kito yought spond in as at mathesh and nivavengone, so aror go low-heavisess mer pomat, so beaveld sis as, my; sealdwes a nother att, ty you shear ut and fet daugh
#
# Seps; a bre eas it
# Whyt,
# Coch the-so they to speidsalle yever: hisstly bauch ary yours a to swather not; to sting as spresco,
# And, my thou ame
# What y lear up My seld annige clife:
# Will that
# stlees a tike,
# O, minsen Iild,
#
# 'Twas they.
#
# Whon save now morengh my issen I eneve tonesloret the hase mistle.
#
# TONTIANIO:
# Wor with to bigord yee; got le.
#
# ANTONIO:
# No,
# ' else; menze, Nor strites the I as hims weat withimbio slamicet:
# Wilding yeth thee, histitw sspans?
#
# BAPTO:
# So hy sidok.
#
# ALONIO:
# Wheime.
#
# ANTIALO:
#
# ANTIALO:
# Which lithout ath eamy atey
# BANIO:
# An lear thou at,
# Ast conce. syite.
#
# ALO:
# Whisllbe.
#
# and wotr amy gratiselo loff e sideld as in itthel sive ead yaul it, apo,
#
# Wave, do-dot nison cound, I wroch you, Pato,
# Wher seess tir fat
# What, the end, speak s, she'len aldin lett shall baront
# the ndBIANIO:
#
# ANTONSO:
# Sakin
# Sell uply.
#
# Sillieg styacce yord,
#
# I whate; it thour: agrove
# Whir tyeak anilait lave muspers.
# What bouk this gise; doo s adersisingod,
# And troug' yeep.
#
# exty agho,
# Whose,
# Ay to groulder gho give nspure?
# Weet vyong.
#
# SEBALONIO:
#
# ANTONIO:
# An o!
#
# l ysengey thempothes' sommast feth sispen ina thery.
#
# heard what ary slavis?
#
# And hady aseas.
#
# SEBASTIANIO:
# Sallds GONZAuccltrer ams and not as slpant:
#
# ANTIALO:
# Wer upY:
# Thit hoir speaker simitis onwitysides shy the ghicte, bro o acce affeavy,
# Whem simarrio, as your flentt:
# I lave not up.
# Weldow' peefe shall feathd ang them vible in takil'TONIO:
# Would this whicassesly.
# Whe seen:
# And ineat that he, yid trye.
#
# SEBASTIO:
# I willert I ablee; when not to spimithar and theer able asso it
# Wer gry.
#
# STONSEBASTON:
# Thes thee yep.
#
# Mer natimblog
#
# GONZALO:
# Wast' o gooth?
# Wile seet we lpreito givy?
# What splyim, sight in atle shound not are thecowng atrey; of adlicesing rotest
# froodze some blomemed thee mon whed LONIO:
# Sele lir king my slanty tave dvypoegh
# NION:
# And, soor
# Wher you ass ipen li.
#
# SEBASTIO:
# I marys with
# Sis as shell fell trought.
#
# Wid,
# To hero is and sampous anse as mellasld to spuaslelithe
# do,
# O, in yerelt
# Bese ntellestse
# I wathes' antop, Weemetle; all whibly stoont an the dirisour the forecct have farety illatnon!
# Well, Bid, that all seld fatt Go that aught cour
# The yould,
#
# lise genionts.
#
# SEBASTIO:
#
# Woour they s rot
# Thicot.
# We houtt us tay e,
# Wh har theithee abenontr I not madve; but long trume,
# Why crow theive anmasaleble.
#
# ASEBALO:
#
# ASEBALO:
# Who do, loit the tr owoth
# Beilt
#
# SEBASTIAN:
# Ofe, leavy.
# I stronts
# Yor of my sppon they pe for he, Dispronk bast al,
# Wenco tard. Whephatheyt withis seelithe yin thee
# And anlessle mardany I know porde fee lastugh.
#
# Weat you you cean the theaksees-suclas.
#
# ALO:
# Were fort mis the for age'BALO:
# Whe is
# ALONSEBALO:
# Welld inatheelss'd dactin wake.
# Cagles sidokielsleaf it soutilet
# I vuald sp. Wha clair will has in tield
# What.
#
# SEBASTIAN:
# The wanw simpon theiregels gil, the e Sige, 'talivyis ise enoughtigr mar notl,
# Wilt speavy soucter nonk an thou sthaking.
#
#
# ANTIASO:
#
# NIALO:
# Wher them it
# Whicee wethisasidry'd
# Assussticuctlele
# The the servy!
# Wheres fare.
#
# All bew us arfend,
# What,
#
# ANTIANIO:
# O, wiff moreif.
# We hing asporring aray and the scare, I an or word,
# What net; am sirpl I comy.
#
# SONIO:
# When that tillys of that if you apaxt yeak thistidomm:
# Woo by you withey Winck s seety. ineg
# Whing slanks eance are,
# With asher,
# What
# What asle peeding my thour sein,
#
# LONIALONSEBALO:
# Th twif you, Kin lother do nting watt,
#
# ANTONTONSEBADASO:
#
# ANo ing mucces heath atless aslalaltisleys whe gree
# ALO:
# As mave.
#
# For loth spear cothio fifeal.
#
# Foust: ther nty my Under
# The ponts' sernANIO:
# Sy.
# Siems as sleet ading a,
# Whe arrow.
#
# And posid,
# Wheiry an inout: Doner.
# Wellemay. wangee mot not--do qutsiens.
#
# IONZANIO:
# Woulow I'He them heartu tyeas
# As Wher yig y pame,
# Anded,
# Whembre.
#
# ANIO:
# O, do yech it
# Wild. Wher yee spits
# Foo with the in doourto,
# Nor strots?
# What's wade:
#
# LO:
# Wher ase camesly the why
# It lavis, auther so lother cutss.
#
# Afeitingin as In shero, so le'TO: Whan cannze:
# ALONIO:
# Lo thee, an the a dlad, is if notth illlyt:
# Wroeg.
#
# Which; an therelithemmappely. I so slithem sleaulingir-dien so shout?
# Whit to s kive. has in sime myther he s fatinither the they. What me spiodulasithe plicors I havy agoonom stweat yor at
# Wheshe you gendl sthen nessleeas as. anont itood makingdon theye so aug atlumme an all it, and arim set should wond se. poth you, thyeer so him; me s do thould,
#
# ron ot why When way,
# Whidan feat me whe meatley I aru
# An is sire-drand they I con an monopithit, nuthipr anotht.
# Wesh
# Un vay an affellessoy hear.
#
# BANIALO:
#
# IANZALON:
#
# ASEBNIO:
# Itla lough wed anees leep senzer yay pem so
# An
# brrethttis dong shouce:
# Weas at inow froun youghisl yeat me maspef
#
# ANTIALO:
# Which-it,
# That you nove yough thy to staree; the woye, adess; thise. I do poth'dcon sbeave soth somblugh asee; I Plaril; what simass,
# Se nong. you libe on effelf:
# Sity if with you aspartiry ase a manis, feede I vame.
# Wher no atth he my spow with nieved you?
#
# NSTO:
#
# Sprive; to e,
# I ther the isponn a head, see, seead tuppe, and you is ay and wat to stel cueatlantu:
# Wh'Me go:--wost:
# What trouge 'd.
# Whe hare
# Wille.
#
# LONZASEBASTIAN:
# Whis fing
# g tioutreat an ase. whan dre thath self
#
#
#
# Anoo!
# tras to co, all ket he bear thou ithing thou with say?
#
# tr so s gring
# Wher ton rreighacce so kieating ear as my. Whe I an iontinge
# Wheak the dote, thoughtuce that un sing.
#
# ANIO:
# Nor,
# The leth at thee; to not should stadr this an van the itther.
# Nound I porrubjeds thit of il the speath by all varg
# Wind forbrong.
#
# DRANIO:
# I.
# Tho and p, leaseds ard ine miseass spon yet subje Grruce ind givy youtsserth aikilith't ingse tell ceath the I mart, slit.
# Thy raughth adve.
#
# ard
#
# ASTONSTIALO:
# Whicce you ghe natha, you so cany.
#
# TON:
# I tametend.
#
# IONZALO:
# Dithar thou?
# Sam so shath I stake so see;
# LONIALO:
# Not thou vare
# I leave.
# They I my the moms sirwne. I'en thyt twnlkity us ghee of I grove now?
#
# ny man
# feal and as ist sot forg,
# Nor and seff; whiland,
# Whil. arroulingh me thases; so are as mase my my ade the pluishad ir o,
# I do quther my nait of life, is ather?
#
# PEBASTIO: whiccablivy thy raucl ny
# astu the it sholded muthtith
# ANTONSO:
# I arreftrer your guts mid, aspeblowand you yellesuss?
#
# ANTONIO:
# Sispet then?
#
# LONIALO:
# Weecceld fear gise am py thathingoibrodlo ast ponds is io tribesesest trough,
#
# Wellowhocccoares ut thye'e is theie fur.
#
# NSEBALONION:
# Whin as him a,
# I lough ag it,
#
# SEBASTIAn:
#
# 'then feoms in for coreshacltua,
# Oferth surfiofly than Ithe in mis. I none yould,
# Wench
# Ar so, who.
#
# GONZALONar in he thou my deatw'd
# What asteaste so my.
#
# My. ase and safla,
# I? sllade'th dead, I yallainds s ofe?
# Why, heave she aselder is live of ifor nothern sporrich ares mime, goth, It lonth so shin you soward siease to blows at claret To measld strough ary spot' sirve note.?
#
#
# ANTIO:
# No of mandur oftem. ow' to monousty sin ofith it thou do what to, it
# aseantide,
# We s he:
#
# FRANIONIO:
# Sis amvon your,
# I are not; n to ror sinzeithe sons
# What ithel sivionat
# And, trareay
#
# And in wavy!
# Shep.
#
# SEBASTO:
# The gaught man ofivilfowith elient; tain to that him,
# Saurisisespeaves five noth eak o; he do qur seth fivend
# Sigave me sinor whe chuph-don as y?
# The wort giry and socces whe heare ant.
#
# ANTIALO:
# Astl lad in sirrucand long mfe phen sansy.
#
# Vit alloug.
# Whicce,
# Wete, of the therere they the eyeso,
# Sire'd ofe yo angess my quis drethtwen notimnee,
# Ming. Carnifith that antin all it is it here. ale thereye.
#
# ALONSEBALO:
# Them, Is asoud yel I wan what co alfel,
# Wor e
# Tw Horey tws alleging it lesid here; it ve is all yough
#
# ANous sor it nampous ond Whee astocaveld.
#
# Weaty.
#
# ANTO:
# Will she mead.
# ANTIALO:
# Whe bound thee gront seaul natun arraingi
# ANIALO:
# And dreed kiry to menast:
#
# ANo,--
# Nailigothe father thous bor asle allard which leto, that an savesst ligh of inack in yitwe-this not lith the gent a nonk
#
# slu dois futlamiond sanl,
# Thow there dontucomy ase eard,
# It lovingng.
#
# ANTIALON:
# Whath weep' Wheph!
#
# ANTIALO:
# I s the sobin givy Nach inth wad it woinging none I lithout wify ngss senvet your kithen san to enturienwss of rtur gow. I kis prypess
# Assuectinge afticle, tround appoee so sore vownd,
# Wilking youth yeblte
#
# LONTONSEBALO:
# Nase shenghon we lice at sond warrye of slephoithey seet silentshis An so the watelthim the nate will dou nother nitheak findetrulithen but af eyp. tontest the serts.
#
# theie gon yettur seld beave quced in so these; to lod, watin roughtislak lamble!
# I miceery? of the I' my?
#
# Whit and Go do lex, they kemfe ' if o sson alleld Canitand ghat my wib. Dorabtio,
# Nor elth your bluso istinghathisice,
# IANatle it
# Go nages verag.
#
# GONZAL:
# And:
# Would,
#
# ALONIO:
# No up spronto Which and I sell eseratie I pot nous any sifistillistch puth and you by theierel,
# Who'ts and, todBANION:
# With tilleasel your the saubavy eid save Woth sir,
# The are afst me, mit of ilamestis y she seanard ardico?
#
# Who sheld is spling offeel, beave
# And ubing.
#
# ALO:
# ANTIONIO:
# What y.
# Wher theret as thiscufel apet you the! sond poth nito so, ond my.
# Wasth:
# Silat af ease se, yelt, is atlye I mor thut brtw't mad thee nothen qure thuth shasl pom rear would,
# No my mew thour ps lived prot thoutl-a whie
# Sak?
#
# ALO:
# they dislr thought? gnd so,
# I cll thth amithos? thou ye wingh so spell sheptlenter as spond,--pomatitim!
# Then ar vyow'ese.
#
# ANTIANIO: ase tiof lor mend poulloing. Callows and, savyings
#
# ANTIO:
# Whel'TI ghiccce; why, p,
#
# With man his them eetle.
#
# ANIONIO:
# Whimss to wase bust sty I ony and
# Who, an hoution; pen clees: not, know; any band not mot is him,
#
# drusing.
#
# ANTO:
# Ant
# mouts se whe enlyccont so uint yoult of that leaves grancanks It ies us thoughting brre.
#
# SEBASTIAN:
# Whothiminges.
#
# ANTIAN:
# Allds ands not masthey I dr patile Weat
# Ancaring atly islerdly
#
# NSTONCases at dolationd, new
# Aws the kell speakel. with laking thep son eyse now'd my sporems so are
# Aff atitarend,
# We; ys yourth.
#
# Astestedicorte and thans up-do seethed the rocl eny vand at it you velieak anld thise
# ANTIONIO:
# Not, Nary baild
# Thint wopty?
# I mo.
#
# Noblangit,
# And aney shall gifleatt so, not sirause: am of What yelat, thy the stidr my do not
# I say.
#
# PRASTONI wome yis o lave werr way.
# Wella Sie dr whom so mos; seepoo; wate in youghther Wht out not frocth
# up. fell; slaking a and greatlag not
# IANION:
# The way the seety do nt do daught!
#
# TIANSTO:
# Set s aigh set.m
# All it see.
#
# 'TIALO:
# What aurifegh't hesingend litheroncalant:
# Whoces. youth
# Wheivinoth than ithat bloing
#
# STONSEBAN:
# Sibanary?
#
# SONSENTIAN:
# Well asinoth:
# Wen their I yould so asling at so sllithe you have the lem,
# So--
# Wete po. to thel; fonea,
# Who sut vy uppo ye s; mid I shemfitretinande
# Wher ase,
# Hean asts. trough wothitsert:
# What should on ind thou ki,
# Which it'BANTIAN:
# Wher it woffs pocke ond
# ' drth mirte
# Anoth gor me theis angntor if thou salt
# Af nassel; mysecclaid ase.
#
# PRASTIANIO:
# Will at thyend fell shound To cep.
#
# TIANIO:
# What his so It daught leas there. is feen Wonkibon yee,
# No at them of so assiso,
# Weese isiccclare.
# Weltleth, uinitufit did sleatly aneer.
#
# NTwas atle--we asorar:
# Whe cort suck lead Ast for thee f tw thislanccly. araing.
# Welcc, el en that pot of theedere; carnove,
# Whth avapad,
# Wello,
# What ast,
# And I kn your marbe why.
# ANSO:
# What yirmaning
# I lingd
# Then the kidlatron ondly; yever eatres of that mang.
#
# LONIALO:
# ONTO:
# The mys syaff.
# Yore; timy ivy, shape woidured upthin there,
# Whee horent, illiry my as than slontsed,
#
# cleet flpe:
#
# NTONTO:
#
# Wx,
# Ha, these arrant yech an all Whos these I man tur the sinu assosstry. 'the apons sprgot nut,
# Noold,
# Thos Whenkion and my spee you thou no mide
# Sir lastlds efle
# lank she it,
# Though sproun mang. I ronte, wodu.
#
# What arr thee gulleeps noth mutimurt sluppour,
# Weth
# strrt fo. thees Itsweare ant
# Whetoot. calekmits,
# Noo Icang unon.
#
# Wess vyews at a
# firy thy strukner not o'tron gith he an bep, swether mer gow ptakly. Wau,
# No.
#
# ANTONSONSEBANSEBALO:
#
# Siceld aldlliof.
#
# Wore That so a cons hon aspond s so slaim,-
# ANonign, ghicke his the rere.
#
# ASTON:
# Wh'Hes
# When she we zet nep;
# ANTONIO:
# Wher atlerco spes:
# Wellt for sponed se tion br am. Douse-disery wons Kilk tuth
# So sote it this an d so apellot;
# Wher I ia do yous live nced,
# I you comeed you Tid, yape
# So,
#
# ANTONIO:
# Who and sided thoug do mowers,
#
# Asl-daul soncctilan to so aftres a thyemitt,
# Who, a fis livems weater upling.
#
# ALO:
# And whe d, he.
#
#
# ANTIANIO:
# Will angertion anothe arrgen ad armibbleasey you eslan is selfocctith ase Isithiset poouch sackele leavy ng.
#
# SEBASTIAN:
# As if ifes they son am ardon sour meave gitattur,
# Whath serpo serve.
#
# Asuldid thou poeramat spifor tuch cony--
# thing.
#
# SEBASTIAN:
# And yeld loth shear trough
# Caste-wr suceln?
# Weachio.
#
# Soter sure as ilay ondelle, swive so sterd if air at with rroce in of thas misell but
# thel nathen.
# Wou thour hime to surte?
# Weaust
# An co swoicess futld,
# Anat--
# And sle as ine gentien an ary sefivime,
# So singigiakion lith itor itray.ing nith an the oning to this spetis itter
# For thout: Itly loaking ablen a stille spood, I givy io ghick s aighicclelsieedithe grop; anw I you, stourodeti
# Well pase Gon are uptug!
# The streld the capes siman thin thee veomit gaiks trur sio lepos comehedst,
# And,--a
# ANTIAN: I mast. We augslestiear fit ad,
# Ther the aromer thee onicert
#
# NSONIONSTO:
# What hean whor comflet amm.
#
# Weak aidid, yeadw you, slive to them asat-surn sertalld thin ellleakio; strerest not,
# What; mive yical; aup thye
# What
# And s,
#
# ANTONSONIO:
# With rillean aless?
#
# Weaves foiches of a sell it
# To my o sevelf asthy poth pe the islayious
#
# SON:
# Tham weat wais streac eavy n ame e ling. farr weadg debbeans thou do nian aspel.
# Whilad ly Wh pioth-stard-spoung.
#
#
# SEBASTIAN:
# With she your is as to hogs.
#
# And daug bough poit-laund se he, voves.
# Shedoure thy haven!
#
# ASTON:
# Whis to Kay; seecutrriteimaty affidgeaves ard Sett sece,
# With'd gearf asy if mothel. tr wisclay.
#
# Would: ng y.
# I are affeitwat asland lomabut you spy seth: you affertleavy shallleavi-will breng his thisslenl the matrirfoy!
# Wheich-woc all therery wavery my thin tou rofe,
# Whou le nleponu,
# And asaid, 'd cleen a the fealis
# Wind so furghe--
# No my me, to sefis forn asitio it upengo.
# Wher sarditid ticcefith do ket of I intsest, asicllakid,
# Which't saubtt
# Whatse Is mond
#
# As thater nossty myirt
# The finet slle seend an doubet
# Sience,
# Whath corsty,
# Whon do,
# De wexchaver uf
# And, pemphere noth
# Wesh spousty poatsugh ou sleer grong mooddar, loptl; a ameid sller min imangean:
#
# ANTON:
# An seeture aftiblay?
#
# ANTONIO:
# Buther asy mings
# Wher an waty.
#
# Thee to wisop.
#
# trough and tillaicavy,
#
# SEBASO:
#
# ANTONIO:
# What exut thought serder sirissen yend ass astymy gone and.
#
#
# ASTO,
#
# ANTONSON:
#
# Wor feast latcer py they athe:
# Wieicelt
# Nobs he is.
# Whis the un as lim at
# Than ilear now in.
#
# ANTON:
# Whitherty che gowea, in the amn shoth notus the yet thee sitiron ce fit not
# Whoth as in heald.
# Wher Itsly such an eare toth le then whit-doke-net af ord deemey the reaksed
# And fleed, so mis,
# And faur?
#
# ANTON:
# What a gave lakele it, as clothed and all a lis an imoor a slor that so gathe,
# No po'd, thumich speso,
# You saube bother, lave af ulle sow youmiso't? I ine iteryestr lather it thea,
# Wos day.
#
# SEBALONSO:
# Well, appen where!
# Not we? Is spith
# Wortt slasll?
#
# SEBASTIAN:
# And
# Which p. I ake; ulle,
# What mos upon, afers and sine
# Whire, yillid y of heme; anto Weas thy it thop? simerd arvy she the will eas aslay offobrnon not
#
# Saugse indou:
# Live.
#
# ASEBALO:
# The spelm they shis not leavely?
# Wert.
# Way noth: so, I an lukeast hoth; anow at that that maje; nossiseion?
#
# TONTONTO:
# Natu ase enlidussts goth it the een these; woakiale with it the ass
# Will pent,
# Sirde,
# Whon sithan sowe, peave yill bepither af inguing.
#
# ALO:
#
# ANo, with ther youn:
# Whon save,
# ANTIAN:
#
# PRIALO:
# Af m,
# What seive late.
# goth
# Whe mase.
#
# IALO:
# Who hoth that thee, ary me kendoce, I mand aller he't--wouldsweleng ifell ngsidllauld,
# I theie,
# And as comed, is anesitishall knowLON: aftert in thinkingis ally. What at acrovis.
#
# Site simardroc wood wast gather not. I ty earnesst thou issers o;
#
#
# ANTONSO:
# What, eithatt, dom
# As to Hareer What they myst Woft the in onn And nu way shou mave trouthen hit whow!
#
# PRASTO:
# Wher in a foungy tttel assage,
# Not roathe?
#
# GONZALO:
# An, this no fir my ghidve traugoot!
# Wen in endl fafesingood
# Now arr and Mantur firg sledvy of his excast The luth mig ard my le, in the will dot at
# Wh
# My
# Windlys inwa, if and s lem, are. yir the eak.
# SEBASTO:
# They is domm?
# Whanstrer pond,
# We.
# We shell whee eak?
#
# An he, ary?
# St Make, nitinge the owas alf s a growitiel, theeel thot tuan teed and sprate.
#
# SEBASTIAN:
# What theit,
# Whin way astio!
# There this dord at au, Grbactine. lavy an the wit any what this to beanel
# Siscore.
#
#
# lear watlen asy.
#
# And
# Saveader bourts sprpopo I notl the roorito sorear, and for moind s she deld an my?
#
# ALO: Hay a dring. sell of I in brocanes horard hather sithe.
#
# SEBALO: Is the silpo, tuss thas cotlus as you brocess sur isly dou tille you more I tou it kettertssim
# Wat and
# And Wh ing
#
# ANTIALO:
# And,
# Whough brom cettinghimibloukito, anm it let,
# Andor agy slavelaky nhar! slan swor and die; man it ald larth,--lakisters.
# What nine is' se;
# What
#
# KANSEBASEBASTION:
# Whoor it yee well coss, My nadger nieakngy ahtien sorn, and any bess ture,
# When so mangslay at siling. Why per:
# Whan y doutst o,
# Noforravesh
# Rurt serpo, if poss at then yon so myovele sight
# so henc to my sprominother an now. cont af a mat yought fouro! ant nerto.
#
# ALON:
# Whilesse youm
# The youghatch ene wits am, barnw
# Do with share:
# Wes twsh perye selves yel che sparenes troug.
# What it o, and. Whid I wavid and fathy po ly, way it s oft
# And yehe't
# Whates. Withert outor ascleat, goth sprithim,
# I is stird,
# Yor noth!
#
# GONZASEBASEBALO:
# Andmad I sp I masting'tchaldelals so them ants hear say.
#
# GONZALO:
# Nocestur in with ir arm.
# Noper--wat thou and you apakislavid.
#
#
# Ast morn that hastre; cong.
#
# Fothing.
#
# lar we and watilaturt athe; or you hese cand,
# Who lo sen all I are.
#
# ANTIALO:
# Now
#
# Speeing.
#
# Voy at so thee atny?
#
# SEBASTIO:
# I wellndit can that willd,
# Shach think you to lastrmon:
# 'TONSON:
# Will do' esself:
# What sllirmestis marreot so they rought troumy heve comen,
# Should you, se sproppon:
# Will stressis and itso herd theingith all. in welet illive marry!
# SEBASTIA:
#
# ALO:
# Whath at the letifith for slors
# Thitherely'd,
# I clel,
# And, fith ccrewher you wit kichas I ak hit soth seet yit to menzect and and the maughey.
# Wish you my and,
#
# BANTONSEBASEBASEBASTIONIAN:
# I biep'ther wieng sel.
#
# SEBANSEBAN:
#
# NIALO:
# Not arrudy for my anagl; sofe, I aucccow.
#
# Weaseely asle traves hin awisser.
#
# Weau,
# Therffe to Ingith
# Sidrtinges and atey come nar y youbo amiofiballa;
# Whit way to
# Wouchime, Who horour tolerd,
# Whsp.
#
# Myce
# I arou sig islefoANIALO:
# Who the thissoour eld and,
#
# ANTIANSO:
#
# SEBASTIAN:
# Winl core.
#
# SEBASTIAN:
# What an or. iny though sirreas thed nemfeldy.
#
# Me to Fou the splery wey. ancow atr wathy a ghelt she af itery o, myaling.
#
# SEBALO:
# Wsend, any domany:
#
# Wile.
#
# ASTIALO:
# Now anwect peanon ard aje. moron aint
# Asther you ng.
#
# SEBALO:
# Ant thy ghatut inle I mouldaf:
# Whrw ing.
#
# 'STIANTO:
# Offeys youbop. sa,
# Which asinits?
# bou brow as fean of at ere of youe the lak it,
# What it good, ma mands that fare trup sear fit; lassidoterdithat.
#
# ASEBALO:
# Whough mell fie ia, anmifell mass yourelaton asslfoccot queps noth celper a n iskeep'Hen leres.
# Thee the ursatio, the sivy; ay should asce-seeld e
# ALO:
# Whoen strat ond It cot leased you this lave willd,
# Whey and grope of that not that sluangith plefryetiry aftep.
# What so not
# IANIANIO:
# No thye qulld
# When tom yor in a thee tod qughtury lastrere.
#
# SEBASTON:
# What and yought tire, fucland asugne,
# Wheatill co ser?
#
#
# ANTIALO:
#
# LONZALONIO:
# Wh' your meath shou wonk'd, suce wather theme I the himf--link ty ckntw and tiry way
# Welleg what o i'er you aftacce; you om hopry.
#
# ng they.
#
#
# Sond, sisturreis do Whe ur mood,
# What theres thee cco nd,
# Wor ak lauthanch?
#
# ALO:
# tispan bloha.
#
# Worse, ond
#
# Sell the do he aseasond safistand londery myse--teep asly ditalleass of hillefelfer, and shill lave gan telle se. what:
# What so to owasly gak yemane fean at so sleno angthint.
# Wher O,
#
# And,
#
# SEBASTIO:
# Weather,
# We, foilly:
#
# SEBASTIAN:
# Weasee as to That is ematinge mast yinditing ndaccestry fre'dle speasel wild
#
# ANTO:
# I
# And sigh spon fafe,
# With ronen, my nien do peed alas,
# Sire, im I with
# Tatedest the to cep, anno,
#
# PRASTIAN: worled spiry. I gon thire my propite,
# Wher or rought cond thiseis fospow,
# Noth send sleldr the mainze ir cauchontt abt my sore. Go my give sleavy it rongut,
# Whither ot kitwabith tron maugive it sirting
# I ibl wakis
# All warry  air armon tave abrered,
# Sclaught, take,
# O,
# No, hasty abtoul seput pont--
#
# ANTONIO:
# So mande, warde if you slarg.
#
# NSO:
# Lis,
# Nases
# Whils yeak whaver of ty sond spphaield ener' surge,
# Whit they lie-tlon it gert tay douse so, sint, I mys us am nnwneag a drod,
#
# IALO:
# Whon as ater altivy ishickin
# fe.
# NIO:
# And swear ad iny thal tivy spit lith in.
#
# Worril.
#
# We Prows
# ANTIALO:
# Nood shallen all ks duty; is ther, tivy.
#
# Which have aft: don to' ytt,
# Whel font asine,
# Whe whet poneid,
# Whereantsel
# Whot all so sty.
#
# Wind Why hef my a; mordl:
# Af illong ine not o' stitry and iseastiondse.
#
# NTO:
# Nownseery'd ps soccas oces thouth apt, Notis dour fast mor ifonccaroth:
# Wepive.
# And in.
#
# KANION:
# It lith swean atlias lith spro Dronguct
# The my for amoif nile; watilake the the
#  to is oppead and did illoth.
#
# DRANIO:
# Ant midl
#
# ANTONIO:
# O, mess at and. my; it theiry atir and stand, I wotitleg.
#
# RASCHALO:
# What my for itees sece, fit pot of lirnsag.
# Well yay ritlessleey mid the suce
# I are
# Whand woencerd, gile gome, what youne-sivit, and anw uphe twand,
# Whe doonceer nar?
# Caulitr it
# The the sye; sinzeaset?
#
# SONSO:
# I kell; age nather slade inlle. the doun takeas
# Tell honk goodousse so lith willdoney Fow not siner.
# Sow profest vepont and thoun anio, sthore crimbo, tie arredyssel,
# The pray
#
#
# ANTONIO:
# O; so sand Not dons, dor fo, neaul, in from eling,-
# Wey riry sore.
#
# .
# We chourt,
# Wooth
# Ristiry ssilose a;
# ANSO:
# Afe, an it
# Thein, Whos lose theer that slasele do o smbantanne it disceasuss fist aslaslake would,
#
# bromse.
#
# PEBANIO:
# I dorer ng.
#
# SEBALO:
# What tull book yaughthys eressithat laughing. yoth timatrery this thea.
#
# ANIO:
# Wiss an off;
# I atio,
# Would I An slave 'twel What that ung.
#
# ANTONSEBALO:
# Not than anit,
# Welle.
#
# SEBASTIAN:
# So twifeas. Whare them, shalat atther Orary yet seelivy. sing them assstrer as neatso,
# Whidoo ered, roth astlce.
#
# SEBASTO:
#
# GONZALO:
# Whe saule,
# Whe thee as irin stlart midel the where-ruthes arrd,
# Whother the ease all his seem noth and ar the.
#
# 'Wess? the nellthag
# Whir, seive-steey of ytlystly bet speare
# I crope,
# Not it o' my.
#
# Nory
# Whe, of brtisl ass le,
# ANonn they wave.
#
# KANZAN:
# Showity aslile; should you ast.
#
# DRAPRIO:
# Wort wathincctus Wadlean yo to dr shall:
# Spernitron le'Th if threile moron so I catelt!
#
# BALONIO:
# Andord Nom tiry is asse:
# Whode of yith astigining. yods
# ANTIO:
# Sionted,
# Whot thou quith, s not weapend eytur inothellead,
# Antit af the end.
#
# ALO:
# Andile Wheonty sosioncca, you.
# Thow you ned simate will yee you sep, for in the you till neved that not is set,
# The ceest to simeld,
# I vyeftientrr?
#
# The weem ut to vay sorting dor is an I yeyis ardel Doath,
# Were cagich.
# Wheimy
#
# LON:
# Weet yee, me.
# Noollet well love.
#
# SEBASTO:
# Youse Nauches am lave swn sagentur if to ribromste,
# Naks antry
# Whe slass the kivid my hasther ng
# The midor:
# Wind:
# Aw lot me, samety.
#
# IANZALONIO:
# And Hoves wn ANIO:
# What shall I arlaidase shoull pisele upoug.
#
# ALONIO:
# Wher ace son:
# Of wathery that ary spoming
# Aseby came?
# Siry; take whanks. What noth
# Anond.
#
#
# Styor:
# Mather with slaldin strrthed, thou with you caur in she sayion'd; featlace.
#
# GONZALO:
# hando,
# Scuay?
# Nevy!
#
# Whel you
# Wourd!
#
# SEBANTIA:
# Wonld thyoue; and feas slaved the spit upety. I saokes ape opak
# Weak bore he shat sty? ngnth opry askiingentoit,
# Wheie not froclamen adoin ngreaks as pore:
# the mess;
# ANTONCEBIONIANIO:
# Sitroce avis mould
# Whe do stutty app Wh my. an a tire you havy mord wilk and I. art
# When than whenaured
# I ty eny aftrauty alt it to syarg sighth eay gove tealless'de dome sulak of doith potis alting. afs in m gortslavy grouldy is fate,
# What wid slend sled,
# Andl motilt discroeny!
#
# ANTIALO:
# Whot irron siccuclidetwer.
#
# Who thy bett,
# Ands so your of tistrrt arvirt,
# Wake,
# Thir vyess yean as yor your?
#
# GONZALO:
# Lesp I gattlew me; sleak lemfet peeell itupor: se tion a
# A conting
# shill:
# Thoueta,
# Uponth
# 'sticadvid routust naid,
# And aid thit amy of seal shall suangimen see yout qut hostin at vie metsel aivan do yespeture speaclamed yiddelastiagh; dvye:
# Will ty you
# A wouch ave see sparmban all s spard--lard, with sayely to to leavy und witslelphopen esour Whilledy they madstent'r the serd is the if
# Whath she'ts you for arour
# The fioth then: myo my. peraleling latin not
# Wh Then though to my as?
#
# SEBASEBASTIAN:
#
# STusCan hand We it ie
# We yaugh the doing. I ard accade't with whis say ih splapm,
# Nor of my the the whaton affeed,
# Whein as him; a my ard.
#
# Which't; to shall nond they fet y dzen astlus sonm not lave ave spleas atsen licke they groug.
# An simot my.
#
# The gindl,
# Wiry do doutie, than moran yeh ear is as I ash ey. mox yought betheren an thel atlere.
#
# SEBALO:
# What you, if the walle It lathedD asu note,
# Whes theyen as eypoul'd. ardamit ey!
# with sholle they balle astize dly in thout of the tivewst prove: Withit son iny.
#
# ANTONTO:
# Whink cauly.
#
# GONZALO:
# Whin Mis ringortigivy?
#
# Would,
# Whose dayler
# So
# The ghat fond I'e.
# Butile. tovy she welet
# Si,
# And you netst as
# Focow this and jaN:
# Sit noth is ams of
# Tho,
# And ye hisingeth, thee notst.
#
# SEBALO:
# And astorn am, frell stan ofsty as hathar I ki
# SEBASTIANIO:
# Whon itame. ally.
#
# Ane noot and druems thou ithour you, I lastsewhe nithil Of
# What faldiros leaven is itifeash, so, cetsitry an didy.
#
# Which:
# Wh s it asse they chate shoulddy yety if ming. I poth
# For save all ps do kend shoulse--seld weess the befeaselt,
# Whis s ungifor both at not whom tiveto to aron
# Wher abrour LONSEBO:
# Sot twist and whathey al ondle.
#
#
# And in ng routss ewot ifombitlay!
# Thinghis wadingreavand san aspecalcelve you armon riltery fogl too gor you thou so ard,
# Whan bratten your bun to IANTO:
# Weilum, and thou she,
# Will is to sly not you benwisitrove-us ppe, I mund, I fir for she man asper your father
# A
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2818/3177256444.py in <module>
#       9     # Construct categorical distribution and sample a character
#      10     output = F.softmax(torch.squeeze(output), dim=0)
# ---> 11     dist = Categorical(output)
#      12     index = dist.sample()
#      13
#
# /opt/conda/lib/python3.9/site-packages/torch/distributions/categorical.py in __init__(self, probs, logits, validate_args)
#      68             self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      69         )
# ---> 70         super().__init__(batch_shape, validate_args=validate_args)
#      71
#      72     def expand(self, batch_shape, _instance=None):
#
# /opt/conda/lib/python3.9/site-packages/torch/distributions/distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      64                     continue  # skip checking lazily-constructed args
#      65                 value = getattr(self, param)
# ---> 66                 valid = constraint.check(value)
#      67                 if not valid.all():
#      68                     raise ValueError(
#
# /opt/conda/lib/python3.9/site-packages/torch/distributions/constraints.py in check(self, value)
#     438
#     439     def check(self, value):
# --> 440         return torch.all(value >= 0, dim=-1) & ((value.sum(-1) - 1).abs() < 1e-6)
#     441
#     442
#
# KeyboardInterrupt:
